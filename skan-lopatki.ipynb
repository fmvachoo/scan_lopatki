# %%
pip install pandas openpyxl plotly numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# Функция для парсинга одного профиля (X и Z)
def parse_profile(df, profile_index, x_offset=0, z_offset=2):
    x_row = profile_index * 3 + x_offset
    z_row = profile_index * 3 + z_offset
    
    if df.shape[0] <= z_row:
        raise ValueError(f"В файле недостаточно строк для профиля {profile_index + 1}")
    
    x_values = df.iloc[x_row, :].dropna().values
    z_values = df.iloc[z_row, :].dropna().values
    
    def is_valid_float(value):
        try:
            float(value)
            return True
        except (ValueError, TypeError):
            return False
    
    x_values = [x for x in x_values if is_valid_float(x) and str(x).strip() != '']
    z_values = [z for z in z_values if is_valid_float(z) and str(z).strip() != '']
    
    if len(x_values) != len(z_values):
        raise ValueError(f"Длины массивов X и Z не совпадают для профиля {profile_index + 1}")
    
    try:
        x_values = np.array(x_values, dtype=float)
        z_values = np.array(z_values, dtype=float)
    except Exception as e:
        print(f"Ошибка преобразования в float для профиля {profile_index + 1}: {e}")
        raise
    
    non_zero_mask = z_values != 0
    x_values = x_values[non_zero_mask]
    z_values = z_values[non_zero_mask]
    
    if len(x_values) == 0:
        raise ValueError(f"После исключения нулевых Z данные отсутствуют для профиля {profile_index + 1}")
    
    return x_values, z_values

# Функция для усреднения профилей с интерполяцией
def average_profiles(file_path, num_profiles=5, num_points=1000):
    df = pd.read_csv(file_path, header=None)
    
    all_x = []
    all_z = []
    
    # Считываем все профили
    for i in range(num_profiles):
        try:
            x, z = parse_profile(df, i)
            all_x.append(x)
            all_z.append(z)
        except Exception as e:
            print(f"Ошибка при парсинге профиля {i + 1}: {e}")
            continue
    
    if len(all_x) == 0:
        raise ValueError("Нет доступных профилей для усреднения")
    
    # Находим общий диапазон X для интерполяции
    x_min = max([x.min() for x in all_x])  # Максимум минимальных X
    x_max = min([x.max() for x in all_x])  # Минимум максимальных X
    
    if x_min >= x_max:
        raise ValueError("Диапазоны X не пересекаются, интерполяция невозможна")
    
    # Создаём единую сетку X
    avg_x = np.linspace(x_min, x_max, num_points)
    
    # Интерполируем Z для каждого профиля на общей сетке X
    interpolated_z = []
    for x, z in zip(all_x, all_z):
        z_interp = np.interp(avg_x, x, z)
        interpolated_z.append(z_interp)
    
    # Усредняем интерполированные Z
    avg_z = np.mean(interpolated_z, axis=0)
    
    return avg_x, avg_z  # Возвращаем только усреднённые массивы

# Алгоритм определения начала и конца лопастей
def find_blade_boundaries(x_values, z_values, table_std_threshold=0.2, z_drop_threshold=3.0, min_table_points=4):
    blades = []
    i = 0
    n = len(z_values)
    
    while i < n:
        table_end = i + min_table_points
        if table_end >= n:
            break
        
        window = z_values[i:table_end]
        if len(window) >= min_table_points and np.std(window) < table_std_threshold:
            i = table_end
        else:
            i += 1
            continue
        
        blade_start = i
        while i < n and abs(z_values[i] - z_values[blade_start - 1]) < z_drop_threshold:
            i += 1
        if i == blade_start:
            continue
        
        blade_end = i
        while blade_end < n - 1:
            if abs(z_values[blade_end] - z_values[blade_end + 1]) >= z_drop_threshold:
                blade_end += 1
                break
            blade_end += 1
        
        if blade_end < n:
            blades.append((blade_start, blade_end))
        
        i = blade_end
    
    blade_x = []
    blade_z = []
    for start, end in blades:
        blade_x.extend(x_values[start:end])
        blade_z.extend(z_values[start:end])
    
    return np.array(blade_x), np.array(blade_z), blades

# Основная часть
file_path = '/kaggle/input/lopatki2/3_4_brak_u_mer_sechenie_verh_-8.csv'  # Укажите путь к файлу

try:
    avg_x, avg_z = average_profiles(file_path, num_profiles=5, num_points=1000)
except Exception as e:
    print(f"Ошибка при усреднении профилей: {e}")
    raise

# Вывод информации об усреднении
print(f"Длина среднего профиля: {len(avg_x)} точек")
print(f"Пример среднего X: {avg_x[:5]}")
print(f"Пример среднего Z: {avg_z[:5]}")

# Анализ лопастей на усреднённом профиле
try:
    blade_x, blade_z, blade_boundaries = find_blade_boundaries(avg_x, avg_z)
except Exception as e:
    print(f"Ошибка при определении границ лопастей: {e}")
    raise

print(f"Найдено лопастей на усреднённом профиле: {len(blade_boundaries)}")

# Создание графика
fig = go.Figure()

# Отрисовка усреднённого профиля полностью
fig.add_trace(go.Scatter(
    x=avg_x,
    y=avg_z,
    mode='lines+markers',
    name='Усреднённый профиль',
    line=dict(color='green', dash='dash'),
    marker=dict(size=4),
    hovertemplate='X: %{x:.2f}<br>Z: %{y:.2f}'
))

# Отрисовка лопастей на усреднённом профиле
if len(blade_x) > 0:
    for i, (start, end) in enumerate(blade_boundaries):
        fig.add_trace(go.Scatter(
            x=avg_x[start:end],
            y=avg_z[start:end],
            mode='lines+markers',
            name=f'Лопасть {i+1} (усредн.)',
            line=dict(color='blue' if i == 0 else 'red'),
            marker=dict(size=4),
            hovertemplate='X: %{x:.2f}<br>Z: %{y:.2f}'
        ))
else:
    print("Лопасти не найдены")

# Оформление графика
fig.update_layout(
    title='Усреднённый профиль сечения лопастей (Z от X)',
    xaxis_title='X (мм)',
    yaxis_title='Z (мм)',
    hovermode='closest',
    showlegend=True,
    template='plotly_white'
)

fig.show()
# Out:
# Длина среднего профиля: 1000 точек
# Пример среднего X: [-51.963806   -51.85232214 -51.74083828 -51.62935442 -51.51787056]
# Пример среднего Z: [51.290893   51.290893   53.9773367  54.22498776 53.84056172]
# Найдено лопастей на усреднённом профиле: 1
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
